# %% [markdown]
# Data Exploration and Splitting.

# %%
import os
import sys
import pathlib
import numpy as np
import pandas as pd

module_path = os.path.abspath(os.path.join('../src/utils'))
sys.path.insert(0, module_path)
import utils

# %%
utils.split_by_rscore(
    "../data/croplands3-2.0.0.csv",
    out_dir="../data/",
    class_col="Class",
    score_col="Rscore",
    train_frac=0.6,
    val_frac=0.2,
    test_frac=0.2,
    seed=47   
)
# Out:
#  Split complete — saved to ../data
#     • train: n=20,247 | mean=0.785 | median=0.804
#     • val  : n= 6,748 | mean=0.670 | median=0.662
#     • test : n= 6,751 | mean=0.560 | median=0.579
# (            name Class  assignment_id  rscore  rscore2    Rscore        x  \
#  0      SD4375790    1a         100411     NaN      NaN  0.789374  33.3765
#  1      ZW0230226    1a         100601     NaN      NaN  0.789374  29.9015
#  2      SD4461457    1a         100415     NaN      NaN  0.789374  31.1615
#  3      SD4733678    1a         100420     NaN      NaN  0.789374  35.5365
#  4      ZM1462354    1a         100580     NaN      NaN  0.789374  28.2815
#  ...          ...   ...            ...     ...      ...       ...      ...
#  20242  ZA1003955     4          32427     NaN      NaN  0.804348  30.0465
#  20243  TZ1112739     4          30775     NaN      NaN  0.804348  30.2615
#  20244  CD5145900     4          20051     NaN      NaN  0.804348  23.9265
#  20245  GN0237363     4          22449     NaN      NaN  0.804348 -11.0335
#  20246  NG0863505     4          26308     NaN      NaN  0.804348   3.6265
#
#               y      farea  nflds  \
#  0      13.8475   2.108159     22
#  1     -17.2975   0.721706     18
#  2      13.6975   6.648977     13
#  3      13.2175  46.038912      2
#  4     -14.0875   1.610656      9
#  ...        ...        ...    ...
#  20242 -26.5375   4.639493      5
#  20243  -5.0975   0.484171     31
#  20244  -5.3025   1.216614     12
#  20245  11.2075   0.407753      7
#  20246  11.3025   0.813065     15
#
#                                                  label  \
#  0      3cl/v2-0-0/labels/SD4375790_100411_2020-07.tif
#  1      3cl/v2-0-0/labels/ZW0230226_100601_2018-08.tif
#  2      3cl/v2-0-0/labels/SD4461457_100415_2019-02.tif
#  3      3cl/v2-0-0/labels/SD4733678_100420_2021-08.tif
#  4      3cl/v2-0-0/labels/ZM1462354_100580_2017-08.tif
#  ...                                               ...
#  20242   3cl/v2-0-0/labels/ZA1003955_32427_2019-08.tif
#  20243   3cl/v2-0-0/labels/TZ1112739_30775_2019-08.tif
#  20244   3cl/v2-0-0/labels/CD5145900_20051_2017-08.tif
#  20245   3cl/v2-0-0/labels/GN0237363_22449_2017-02.tif
#  20246   3cl/v2-0-0/labels/NG0863505_26308_2018-02.tif
#
#                                               image
#  0      3cl/v2-0-0/images/SD4375790_2020-07.tif.tif
#  1      3cl/v2-0-0/images/ZW0230226_2018-08.tif.tif
#  2      3cl/v2-0-0/images/SD4461457_2019-02.tif.tif
#  3      3cl/v2-0-0/images/SD4733678_2021-08.tif.tif
#  4      3cl/v2-0-0/images/ZM1462354_2017-08.tif.tif
#  ...                                            ...
#  20242  3cl/v2-0-0/images/ZA1003955_2019-08.tif.tif
#  20243  3cl/v2-0-0/images/TZ1112739_2019-08.tif.tif
#  20244  3cl/v2-0-0/images/CD5145900_2017-08.tif.tif
#  20245  3cl/v2-0-0/images/GN0237363_2017-02.tif.tif
#  20246  3cl/v2-0-0/images/NG0863505_2018-02.tif.tif
#
#  [20247 rows x 12 columns],
#             name Class  assignment_id  rscore  rscore2    Rscore        x  \
#  0     KE1660412    1a         100054     NaN      NaN  0.641682  37.4215
#  1     TZ1133320    1a         100157     NaN      NaN  0.641682  33.9965
#  2     ZA1829949    1a         100205     NaN      NaN  0.641682  28.2565
#  3     ET0616005    1a         100011     NaN      NaN  0.641682  38.9315
#  4     SD4861486    1a         100118     NaN      NaN  0.641682  35.7265
#  ...         ...   ...            ...     ...      ...       ...      ...
#  6743  GH0629771     4          22356     NaN      NaN  0.728205   0.9565
#  6744  NE3643193     4          25138     NaN      NaN  0.728205   8.3465
#  6745  MZ0626848     4          24332     NaN      NaN  0.728205  35.6465
#  6746  SO1566535     4          29076     NaN      NaN  0.728205  45.7615
#  6747  SO0451837     4          29063     NaN      NaN  0.728205  43.3815
#
#              y      farea  nflds  \
#  0     -2.1525   0.000000      0
#  1     -5.1475   0.385614     12
#  2    -28.2675  11.834014      6
#  3     11.7175   0.283413     22
#  4     12.9925  48.927223      3
#  ...       ...        ...    ...
#  6743   6.2575   0.376830     30
#  6744  13.8875   0.891184     22
#  6745 -14.0225   0.324079     29
#  6746   3.0325   1.994765     10
#  6747   9.6875   1.072751     35
#
#                                                 label  \
#  0     3cl/v2-0-0/labels/KE1660412_100054_2018-02.tif
#  1     3cl/v2-0-0/labels/TZ1133320_100157_2022-06.tif
#  2     3cl/v2-0-0/labels/ZA1829949_100205_2017-08.tif
#  3     3cl/v2-0-0/labels/ET0616005_100011_2022-04.tif
#  4     3cl/v2-0-0/labels/SD4861486_100118_2017-08.tif
#  ...                                              ...
#  6743   3cl/v2-0-0/labels/GH0629771_22356_2019-02.tif
#  6744   3cl/v2-0-0/labels/NE3643193_25138_2020-07.tif
#  6745   3cl/v2-0-0/labels/MZ0626848_24332_2017-08.tif
#  6746   3cl/v2-0-0/labels/SO1566535_29076_2022-05.tif
#  6747   3cl/v2-0-0/labels/SO0451837_29063_2020-02.tif
#
#                                              image
#  0     3cl/v2-0-0/images/KE1660412_2018-02.tif.tif
#  1     3cl/v2-0-0/images/TZ1133320_2022-06.tif.tif
#  2     3cl/v2-0-0/images/ZA1829949_2017-08.tif.tif
#  3     3cl/v2-0-0/images/ET0616005_2022-04.tif.tif
#  4     3cl/v2-0-0/images/SD4861486_2017-08.tif.tif
#  ...                                           ...
#  6743  3cl/v2-0-0/images/GH0629771_2019-02.tif.tif
#  6744  3cl/v2-0-0/images/NE3643193_2020-07.tif.tif
#  6745  3cl/v2-0-0/images/MZ0626848_2017-08.tif.tif
#  6746  3cl/v2-0-0/images/SO1566535_2022-05.tif.tif
#  6747  3cl/v2-0-0/images/SO0451837_2020-02.tif.tif
#
#  [6748 rows x 12 columns],
#             name Class  assignment_id  rscore  rscore2    Rscore        x  \
#  0     SD5086347    1a         100124     NaN      NaN  0.641682  33.0865
#  1     SD5448744    1a         100134     NaN      NaN  0.641682  30.0765
#  2     ET0475447    1a         100008     NaN      NaN  0.641682  37.0065
#  3     ET0316806    1a         100005     NaN      NaN  0.641682  39.1765
#  4     SZ0042734    1a         100144     NaN      NaN  0.641682  31.9715
#  ...         ...   ...            ...     ...      ...       ...      ...
#  6746  BW1145620     4          19898     NaN      NaN  0.578704  27.0615
#  6747  ET1688687     4          21463     NaN      NaN  0.578704  37.1665
#  6748  CI0168459     4          20369     NaN      NaN  0.578704  -4.5435
#  6749  ET0553414     4          20811     NaN      NaN  0.578704  39.4065
#  6750  CM0079369     4          20467     NaN      NaN  0.540138  13.5815
#
#              y      farea  nflds  \
#  0     12.5925   8.514325      8
#  1     11.8925  13.741460      6
#  2     12.2325   0.276352     80
#  3     12.8375   0.492945     13
#  4    -26.7725   6.354138      9
#  ...       ...        ...    ...
#  6746 -22.6225   4.313250     14
#  6747   8.5925   0.339276     12
#  6748   9.3325   3.121262      3
#  6749  11.9475   0.414053     10
#  6750  10.4775   0.796178      5
#
#                                                 label  \
#  0     3cl/v2-0-0/labels/SD5086347_100124_2021-03.tif
#  1     3cl/v2-0-0/labels/SD5448744_100134_2020-02.tif
#  2     3cl/v2-0-0/labels/ET0475447_100008_2020-02.tif
#  3     3cl/v2-0-0/labels/ET0316806_100005_2020-02.tif
#  4     3cl/v2-0-0/labels/SZ0042734_100144_2022-11.tif
#  ...                                              ...
#  6746   3cl/v2-0-0/labels/BW1145620_19898_2017-08.tif
#  6747   3cl/v2-0-0/labels/ET1688687_21463_2018-02.tif
#  6748   3cl/v2-0-0/labels/CI0168459_20369_2020-02.tif
#  6749   3cl/v2-0-0/labels/ET0553414_20811_2019-08.tif
#  6750   3cl/v2-0-0/labels/CM0079369_20467_2020-07.tif
#
#                                              image
#  0     3cl/v2-0-0/images/SD5086347_2021-03.tif.tif
#  1     3cl/v2-0-0/images/SD5448744_2020-02.tif.tif
#  2     3cl/v2-0-0/images/ET0475447_2020-02.tif.tif
#  3     3cl/v2-0-0/images/ET0316806_2020-02.tif.tif
#  4     3cl/v2-0-0/images/SZ0042734_2022-11.tif.tif
#  ...                                           ...
#  6746  3cl/v2-0-0/images/BW1145620_2017-08.tif.tif
#  6747  3cl/v2-0-0/images/ET1688687_2018-02.tif.tif
#  6748  3cl/v2-0-0/images/CI0168459_2020-02.tif.tif
#  6749  3cl/v2-0-0/images/ET0553414_2019-08.tif.tif
#  6750  3cl/v2-0-0/images/CM0079369_2020-07.tif.tif
#
#  [6751 rows x 12 columns])

# %% [markdown]
# Visualize Data Distribution

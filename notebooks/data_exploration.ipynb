# %% [markdown]
# ## Data Exploration and Splitting
# #### Prepared by Isaiah Taylor

# %%
import os
import sys
import pathlib
import numpy as np
import pandas as pd

module_path = os.path.abspath(os.path.join('../src/utils'))
sys.path.insert(0, module_path)
import utils

# %%
train_df, validate_df, test_df = utils.split_by_rscore(
    "../data/croplands3-2.0.0.csv",
    out_dir="../data/",
    class_col="Class",
    score_col="Rscore",
    train_frac=0.6,
    val_frac=0.2,
    test_frac=0.2,
    seed=47   
)
# Out:
# Split complete → files in ../data
#   ▸ train    n=20,241 • mean= 0.785 • median= 0.804
#   ▸ validate n= 6,746 • mean= 0.670 • median= 0.662
#   ▸ test     n= 6,748 • mean= 0.560 • median= 0.579

# %%
validate_df
# Out:
#            name Class    Rscore  \
# 3179  NG1830786     2  0.662500
# 5997  BF0384736     2  0.630584
# 1963  NG0130294     2  0.691748
# 3653  BF0689432     2  0.662500
# 2310  MW0058209     2  0.662500
# ...         ...   ...       ...
# 3759  ET1704478     2  0.662500
# 1799  ET0591115     2  0.691748
# 926   ZM1469069     2  0.691748
# 4317  ET2479164     2  0.648045
# 5493  SD5725203     2  0.630584
#
#                                               label  \
# 3179  3cl/v2-0-0/labels/NG1830786_28273_2023-03.tif
# 5997  3cl/v2-0-0/labels/BF0384736_13753_2022-04.tif
# 1963  3cl/v2-0-0/labels/NG0130294_33866_2017-08.tif
# 3653   3cl/v2-0-0/labels/BF0689432_8285_2021-04.tif
# 2310   3cl/v2-0-0/labels/MW0058209_3777_2019-08.tif
# ...                                             ...
# 3759  3cl/v2-0-0/labels/ET1704478_22340_2020-02.tif
# 1799  3cl/v2-0-0/labels/ET0591115_12839_2017-02.tif
# 926   3cl/v2-0-0/labels/ZM1469069_16723_2017-08.tif
# 4317  3cl/v2-0-0/labels/ET2479164_22417_2017-02.tif
# 5493  3cl/v2-0-0/labels/SD5725203_29483_2019-02.tif
#
#                                             image     usage
# 3179  3cl/v2-0-0/images/NG1830786_2023-03.tif.tif  validate
# 5997  3cl/v2-0-0/images/BF0384736_2022-04.tif.tif  validate
# 1963  3cl/v2-0-0/images/NG0130294_2017-08.tif.tif  validate
# 3653  3cl/v2-0-0/images/BF0689432_2021-04.tif.tif  validate
# 2310  3cl/v2-0-0/images/MW0058209_2019-08.tif.tif  validate
# ...                                           ...       ...
# 3759  3cl/v2-0-0/images/ET1704478_2020-02.tif.tif  validate
# 1799  3cl/v2-0-0/images/ET0591115_2017-02.tif.tif  validate
# 926   3cl/v2-0-0/images/ZM1469069_2017-08.tif.tif  validate
# 4317  3cl/v2-0-0/images/ET2479164_2017-02.tif.tif  validate
# 5493  3cl/v2-0-0/images/SD5725203_2019-02.tif.tif  validate
#
# [6746 rows x 6 columns]

# %%
dfs = []
out_dir = pathlib.Path("../data/")
for split, df in zip(["train", "validate", "test"], [train_df, validate_df, test_df]):
    df["usage"] = split          # tag the rows
    dfs.append(df)

combined = pd.concat(dfs, ignore_index=True)

# %%
dfs
# Out:
# [            name Class    Rscore  \
#  19405  BW1574957    1d  0.825000
#  16112  ZM1740694     2  0.706386
#  18087  ET1631878     2  0.694175
#  13272  NG0706735     2  0.728205
#  18126  NG0699898     2  0.694175
#  ...          ...   ...       ...
#  9371   BJ0346146     2  0.804348
#  19019  UG0008604    1b  0.789374
#  17482  NG1643195     2  0.706386
#  735    TZ1814911     2  0.870748
#  18177  NG2348291     2  0.694175
#
#                                                  label  \
#  19405   3cl/v2-0-0/labels/BW1574957_41040_2019-08.tif
#  16112    3cl/v2-0-0/labels/ZM1740694_7112_2022-06.tif
#  18087    3cl/v2-0-0/labels/ET1631878_8452_2019-02.tif
#  13272   3cl/v2-0-0/labels/NG0706735_36657_2019-02.tif
#  18126    3cl/v2-0-0/labels/NG0699898_8784_2019-02.tif
#  ...                                               ...
#  9371    3cl/v2-0-0/labels/BJ0346146_18787_2022-04.tif
#  19019  3cl/v2-0-0/labels/UG0008604_101173_2022-04.tif
#  17482   3cl/v2-0-0/labels/NG1643195_33403_2020-07.tif
#  735      3cl/v2-0-0/labels/TZ1814911_8031_2021-10.tif
#  18177    3cl/v2-0-0/labels/NG2348291_3098_2021-04.tif
#
#                                               image  usage
#  19405  3cl/v2-0-0/images/BW1574957_2019-08.tif.tif  train
#  16112  3cl/v2-0-0/images/ZM1740694_2022-06.tif.tif  train
#  18087  3cl/v2-0-0/images/ET1631878_2019-02.tif.tif  train
#  13272  3cl/v2-0-0/images/NG0706735_2019-02.tif.tif  train
#  18126  3cl/v2-0-0/images/NG0699898_2019-02.tif.tif  train
#  ...                                            ...    ...
#  9371   3cl/v2-0-0/images/BJ0346146_2022-04.tif.tif  train
#  19019  3cl/v2-0-0/images/UG0008604_2022-04.tif.tif  train
#  17482  3cl/v2-0-0/images/NG1643195_2020-07.tif.tif  train
#  735    3cl/v2-0-0/images/TZ1814911_2021-10.tif.tif  train
#  18177  3cl/v2-0-0/images/NG2348291_2021-04.tif.tif  train
#
#  [20241 rows x 6 columns],
#             name Class    Rscore  \
#  3179  NG1830786     2  0.662500
#  5997  BF0384736     2  0.630584
#  1963  NG0130294     2  0.691748
#  3653  BF0689432     2  0.662500
#  2310  MW0058209     2  0.662500
#  ...         ...   ...       ...
#  3759  ET1704478     2  0.662500
#  1799  ET0591115     2  0.691748
#  926   ZM1469069     2  0.691748
#  4317  ET2479164     2  0.648045
#  5493  SD5725203     2  0.630584
#
#                                                label  \
#  3179  3cl/v2-0-0/labels/NG1830786_28273_2023-03.tif
#  5997  3cl/v2-0-0/labels/BF0384736_13753_2022-04.tif
#  1963  3cl/v2-0-0/labels/NG0130294_33866_2017-08.tif
#  3653   3cl/v2-0-0/labels/BF0689432_8285_2021-04.tif
#  2310   3cl/v2-0-0/labels/MW0058209_3777_2019-08.tif
#  ...                                             ...
#  3759  3cl/v2-0-0/labels/ET1704478_22340_2020-02.tif
#  1799  3cl/v2-0-0/labels/ET0591115_12839_2017-02.tif
#  926   3cl/v2-0-0/labels/ZM1469069_16723_2017-08.tif
#  4317  3cl/v2-0-0/labels/ET2479164_22417_2017-02.tif
#  5493  3cl/v2-0-0/labels/SD5725203_29483_2019-02.tif
#
#                                              image     usage
#  3179  3cl/v2-0-0/images/NG1830786_2023-03.tif.tif  validate
#  5997  3cl/v2-0-0/images/BF0384736_2022-04.tif.tif  validate
#  1963  3cl/v2-0-0/images/NG0130294_2017-08.tif.tif  validate
#  3653  3cl/v2-0-0/images/BF0689432_2021-04.tif.tif  validate
#  2310  3cl/v2-0-0/images/MW0058209_2019-08.tif.tif  validate
#  ...                                           ...       ...
#  3759  3cl/v2-0-0/images/ET1704478_2020-02.tif.tif  validate
#  1799  3cl/v2-0-0/images/ET0591115_2017-02.tif.tif  validate
#  926   3cl/v2-0-0/images/ZM1469069_2017-08.tif.tif  validate
#  4317  3cl/v2-0-0/images/ET2479164_2017-02.tif.tif  validate
#  5493  3cl/v2-0-0/images/SD5725203_2019-02.tif.tif  validate
#
#  [6746 rows x 6 columns],
#             name Class    Rscore  \
#  4953  SN0308019     2  0.491379
#  6713  BF0867091     4  0.662500
#  1784  NE4004090     2  0.630252
#  5372  BF0459112     2  0.459893
#  5367  AO2025963     2  0.459893
#  ...         ...   ...       ...
#  4987  NG2316899     2  0.491379
#  5647  NE3945075     2  0.459893
#  518   ZM1506299     2  0.630252
#  2810  ML3427411     2  0.578704
#  218   ET1643093     2  0.630252
#
#                                                label  \
#  4953  3cl/v2-0-0/labels/SN0308019_34046_2019-02.tif
#  6713  3cl/v2-0-0/labels/BF0867091_19467_2021-12.tif
#  1784  3cl/v2-0-0/labels/NE4004090_33673_2023-04.tif
#  5372  3cl/v2-0-0/labels/BF0459112_15807_2018-02.tif
#  5367  3cl/v2-0-0/labels/AO2025963_12671_2019-08.tif
#  ...                                             ...
#  4987  3cl/v2-0-0/labels/NG2316899_36934_2023-04.tif
#  5647  3cl/v2-0-0/labels/NE3945075_23578_2018-02.tif
#  518   3cl/v2-0-0/labels/ZM1506299_26461_2017-02.tif
#  2810  3cl/v2-0-0/labels/ML3427411_14058_2020-02.tif
#  218   3cl/v2-0-0/labels/ET1643093_34559_2023-04.tif
#
#                                              image usage
#  4953  3cl/v2-0-0/images/SN0308019_2019-02.tif.tif  test
#  6713  3cl/v2-0-0/images/BF0867091_2021-12.tif.tif  test
#  1784  3cl/v2-0-0/images/NE4004090_2023-04.tif.tif  test
#  5372  3cl/v2-0-0/images/BF0459112_2018-02.tif.tif  test
#  5367  3cl/v2-0-0/images/AO2025963_2019-08.tif.tif  test
#  ...                                           ...   ...
#  4987  3cl/v2-0-0/images/NG2316899_2023-04.tif.tif  test
#  5647  3cl/v2-0-0/images/NE3945075_2018-02.tif.tif  test
#  518   3cl/v2-0-0/images/ZM1506299_2017-02.tif.tif  test
#  2810  3cl/v2-0-0/images/ML3427411_2020-02.tif.tif  test
#  218   3cl/v2-0-0/images/ET1643093_2023-04.tif.tif  test
#
#  [6748 rows x 6 columns]]

# %%
combined["image"] = combined["image"].str.replace(r"\.tif\.tif$", ".tif", regex=True)
combined = combined.dropna()

# %%
combined.to_csv(out_dir / "croplands3-2.0.0_splits.csv", index=False)

# %%
combined.Class.value_counts()
# Out:
# Class
# 2     30772
# 4       990
# 1d      905
# 1a      797
# 1b      271
# Name: count, dtype: int64

# %%
train_df.Class.value_counts()
# Out:
# Class
# 2     18463
# 4       594
# 1d      543
# 1a      478
# 1b      163
# Name: count, dtype: int64

# %% [markdown]
# Visualize Data Distribution
